# %%
import subprocess

# %%
project_names = """
8ce87c69-a8f4-4200-8e13-ebfa45719c67_0
a7f57638-408a-4322-86c4-193b2f085c96_1
a7f57638-408a-4322-86c4-193b2f085c96_2
a91172f5-5778-43d1-9c66-8321720753be_0
a91172f5-5778-43d1-9c66-8321720753be_1
b0e9f648-21a6-4069-b474-a4a60e8f334d_0
baaf06c5-4bcd-4732-9071-854a3e5f406f_0
baaf06c5-4bcd-4732-9071-854a3e5f406f_1
c1d0a5fa-9ee7-4f8d-92da-13fabe2c6726_2
d1843d8c-df5b-429c-ba8c-1fff659fc7f7_0
d1843d8c-df5b-429c-ba8c-1fff659fc7f7_1
d1843d8c-df5b-429c-ba8c-1fff659fc7f7_2
d1843d8c-df5b-429c-ba8c-1fff659fc7f7_3
"""

# %%
for project_name in project_names.split():
    print(project_name)

# %%
for project_name in project_names.split():
    with open('./script_bk.sh') as f:
        content = f.read()

    content = content.replace('PROJECT_NAME', project_name)

    with open('./script.sh', 'w') as f:
        f.write(content)

    subprocess.run(['bash', './script.sh'])
# Out:
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-441/UnsafeContentUriResolution.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-441/UnsafeContentUriResolution.ql.
# [1/1 eval 568ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-441/UnsafeContentUriResolution.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-470/FragmentInjectionInPreferenceActivity.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-470/FragmentInjectionInPreferenceActivity.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-470/FragmentInjection.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-470/FragmentInjection.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-470/FragmentInjection.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-470/FragmentInjectionInPreferenceActivity.ql.
# [1/2 eval 581ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-470/FragmentInjection.bqrs.
# [2/2 eval 18ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-470/FragmentInjectionInPreferenceActivity.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-489/DebuggableAttributeEnabled.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-489/DebuggableAttributeEnabled.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-489/WebviewDebuggingEnabled.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-489/WebviewDebuggingEnabled.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-489/DebuggableAttributeEnabled.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-489/WebviewDebuggingEnabled.ql.
# [1/2 eval 41ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-489/DebuggableAttributeEnabled.bqrs.
# [2/2 eval 109ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-489/WebviewDebuggingEnabled.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-501/TrustBoundaryViolation.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-501/TrustBoundaryViolation.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-501/TrustBoundaryViolation.ql.
# [1/1 eval 119ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-501/TrustBoundaryViolation.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-502/UnsafeDeserialization.ql.
# CodeQL is out of memory. Try increasing the memory available to CodeQL using the --ram option.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-522/InsecureBasicAuth.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-522/InsecureBasicAuth.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-522/InsecureLdapAuth.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-522/InsecureLdapAuth.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-522/InsecureBasicAuth.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-522/InsecureLdapAuth.ql.
# [1/2 eval 179ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-522/InsecureBasicAuth.bqrs.
# [2/2 eval 395ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-522/InsecureLdapAuth.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-524/SensitiveKeyboardCache.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-524/SensitiveKeyboardCache.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-524/SensitiveKeyboardCache.ql.
# [1/1 eval 126ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-524/SensitiveKeyboardCache.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-532/SensitiveInfoLog.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-532/SensitiveInfoLog.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-532/SensitiveInfoLog.ql.
# [1/1 eval 466ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-532/SensitiveInfoLog.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-601/UrlRedirect.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-601/UrlRedirect.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-601/UrlRedirectLocal.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-601/UrlRedirectLocal.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-601/UrlRedirect.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-601/UrlRedirectLocal.ql.
# [1/2 eval 533ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-601/UrlRedirect.bqrs.
# [2/2 eval 354ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-601/UrlRedirectLocal.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-611/XXE.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-611/XXE.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-611/XXELocal.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-611/XXELocal.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-611/XXE.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-611/XXELocal.ql.
# [1/2 eval 453ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-611/XXE.bqrs.
# [2/2 eval 513ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-611/XXELocal.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-614/InsecureCookie.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-614/InsecureCookie.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-614/InsecureCookie.ql.
# [1/1 eval 212ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-614/InsecureCookie.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-643/XPathInjection.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-643/XPathInjection.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-643/XPathInjection.ql.
# [1/1 eval 519ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-643/XPathInjection.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-676/PotentiallyDangerousFunction.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-676/PotentiallyDangerousFunction.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-676/PotentiallyDangerousFunction.ql.
# [1/1 eval 114ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-676/PotentiallyDangerousFunction.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-681/NumericCastTainted.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-681/NumericCastTainted.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-681/NumericCastTaintedLocal.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-681/NumericCastTaintedLocal.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-681/NumericCastTainted.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-681/NumericCastTaintedLocal.ql.
# [1/2 eval 112ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-681/NumericCastTainted.bqrs.
# [2/2 eval 37ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-681/NumericCastTaintedLocal.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/RegexInjection.ql.
# [1/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/RegexInjection.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/ReDoS.ql.
# [2/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/ReDoS.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/PolynomialReDoS.ql.
# [3/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/PolynomialReDoS.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-730/PolynomialReDoS.ql.
# [1/3 eval 119ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-730/PolynomialReDoS.bqrs.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-730/ReDoS.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-730/RegexInjection.ql.
# [2/3 eval 34ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-730/ReDoS.bqrs.
# [3/3 eval 470ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-730/RegexInjection.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-732/ReadingFromWorldWritableFile.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-732/ReadingFromWorldWritableFile.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-732/ReadingFromWorldWritableFile.ql.
# [1/1 eval 152ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-732/ReadingFromWorldWritableFile.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-749/UnsafeAndroidAccess.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-749/UnsafeAndroidAccess.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-749/UnsafeAndroidAccess.ql.
# [1/1 eval 715ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-749/UnsafeAndroidAccess.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-780/RsaWithoutOaep.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-780/RsaWithoutOaep.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-780/RsaWithoutOaep.ql.
# [1/1 eval 417ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-780/RsaWithoutOaep.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedPasswordField.ql.
# [1/4] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedPasswordField.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsSourceCall.ql.
# [2/4] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsSourceCall.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsComparison.ql.
# [3/4] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsComparison.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsApiCall.ql.
# [4/4] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsApiCall.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsApiCall.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsComparison.ql.
# [1/4 eval 708ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsApiCall.bqrs.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsSourceCall.ql.
# [2/4 eval 20ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsComparison.bqrs.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-798/HardcodedPasswordField.ql.
# [3/4 eval 42ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsSourceCall.bqrs.
# [4/4 eval 9ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-798/HardcodedPasswordField.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-807/TaintedPermissionsCheck.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-807/TaintedPermissionsCheck.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-807/ConditionalBypass.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-807/ConditionalBypass.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-807/ConditionalBypass.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-807/TaintedPermissionsCheck.ql.
# [1/2 eval 121ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-807/ConditionalBypass.bqrs.
# [2/2 eval 265ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-807/TaintedPermissionsCheck.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-829/InsecureDependencyResolution.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-829/InsecureDependencyResolution.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-829/InsecureDependencyResolution.ql.
# [1/1 eval 60ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-829/InsecureDependencyResolution.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-833/LockOrderInconsistency.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-833/LockOrderInconsistency.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-833/LockOrderInconsistency.ql.
# [1/1 eval 173ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-833/LockOrderInconsistency.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-835/InfiniteLoop.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-835/InfiniteLoop.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-835/InfiniteLoop.ql.
# [1/1 eval 95ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-835/InfiniteLoop.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-917/OgnlInjection.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-917/OgnlInjection.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-917/OgnlInjection.ql.
# [1/1 eval 559ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-917/OgnlInjection.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-918/RequestForgery.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-918/RequestForgery.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-918/RequestForgery.ql.
# [1/1 eval 537ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-918/RequestForgery.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-925/ImproperIntentVerification.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-925/ImproperIntentVerification.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-925/ImproperIntentVerification.ql.
# [1/1 eval 126ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-925/ImproperIntentVerification.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-926/ImplicitlyExportedAndroidComponent.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-926/ImplicitlyExportedAndroidComponent.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-926/ContentProviderIncompletePermissions.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-926/ContentProviderIncompletePermissions.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-926/ContentProviderIncompletePermissions.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-926/ImplicitlyExportedAndroidComponent.ql.
# [1/2 eval 42ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-926/ContentProviderIncompletePermissions.bqrs.
# [2/2 eval 27ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-926/ImplicitlyExportedAndroidComponent.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/SensitiveResultReceiver.ql.
# [1/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/SensitiveResultReceiver.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/SensitiveCommunication.ql.
# [2/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/SensitiveCommunication.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/ImplicitPendingIntents.ql.
# [3/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/ImplicitPendingIntents.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-927/ImplicitPendingIntents.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-927/SensitiveCommunication.ql.
# [1/3 eval 415ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-927/ImplicitPendingIntents.bqrs.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-927/SensitiveResultReceiver.ql.
# [2/3 eval 26ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-927/SensitiveCommunication.bqrs.
# [3/3 eval 74ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-927/SensitiveResultReceiver.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-940/AndroidIntentRedirection.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-940/AndroidIntentRedirection.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-940/AndroidIntentRedirection.ql.
# [1/1 eval 620ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-940/AndroidIntentRedirection.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Initializing database at /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/database.
# Running build command: [/Users/lsiddiqsunny/codeql-home/codeql/java/tools/autobuild.sh]
# [2023-12-11 13:59:56] [build-stdout] [2023-12-11 13:59:56] Build directory is .
# [2023-12-11 13:59:56] [build-stdout] [2023-12-11 13:59:56] [autobuild] > mvn clean package -f "pom.xml" -B -V -e -Dfindbugs.skip -Dcheckstyle.skip -Dpmd.skip=true -Dspotbugs.skip -Denforcer.skip -Dmaven.javadoc.skip -DskipTests -Dmaven.test.skip.exec -Dlicense.skip=true -Drat.skip=true -Dspotless.check.skip=true
# [2023-12-11 13:59:58] [build-stdout] [2023-12-11 13:59:58] [autobuild] Apache Maven 3.9.6 (bc0240f3c744dd6b6ec2920b3cd08dcc295161ae)
# [2023-12-11 13:59:58] [build-stdout] [2023-12-11 13:59:58] [autobuild] Maven home: /opt/homebrew/Cellar/maven/3.9.6/libexec
# [2023-12-11 13:59:58] [build-stdout] [2023-12-11 13:59:58] [autobuild] Java version: 1.8.0_362, vendor: Amazon.com Inc., runtime: /Users/lsiddiqsunny/Library/Java/JavaVirtualMachines/corretto-1.8.0_362/Contents/Home/jre
# [2023-12-11 13:59:58] [build-stdout] [2023-12-11 13:59:58] [autobuild] Default locale: en_US, platform encoding: UTF-8
# [2023-12-11 13:59:58] [build-stdout] [2023-12-11 13:59:58] [autobuild] OS name: "mac os x", version: "14.1.2", arch: "x86_64", family: "mac"
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [INFO] Error stacktraces are turned on.
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [INFO] Scanning for projects...
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [WARNING]
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [WARNING] Some problems were encountered while building the effective model for org.example:Study:jar:1.0.0
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [WARNING] 'build.plugins.plugin.version' for org.apache.maven.plugins:maven-compiler-plugin is missing. @ line 16, column 21
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [WARNING]
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [WARNING]
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [WARNING]
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [INFO]
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [INFO] -------------------------< org.example:Study >--------------------------
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [INFO] Building Study 1.0.0
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [INFO]   from pom.xml
# [2023-12-11 13:59:59] [build-stdout] [2023-12-11 13:59:59] [autobuild] [INFO] --------------------------------[ jar ]---------------------------------
# [2023-12-11 14:00:00] [build-stdout] [2023-12-11 14:00:00] [autobuild] [INFO]
# [2023-12-11 14:00:00] [build-stdout] [2023-12-11 14:00:00] [autobuild] [INFO] --- clean:3.2.0:clean (default-clean) @ Study ---
# [2023-12-11 14:00:00] [build-stdout] [2023-12-11 14:00:00] [autobuild] [INFO]
# [2023-12-11 14:00:00] [build-stdout] [2023-12-11 14:00:00] [autobuild] [INFO] --- resources:3.3.1:resources (default-resources) @ Study ---
# [2023-12-11 14:00:00] [build-stdout] [2023-12-11 14:00:00] [autobuild] [INFO] skip non existing resourceDirectory /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/d1843d8c-df5b-429c-ba8c-1fff659fc7f7_0/src/main/resources
# [2023-12-11 14:00:00] [build-stdout] [2023-12-11 14:00:00] [autobuild] [INFO]
# [2023-12-11 14:00:00] [build-stdout] [2023-12-11 14:00:00] [autobuild] [INFO] --- compiler:3.11.0:compile (default-compile) @ Study ---
# [2023-12-11 14:00:01] [build-stdout] [2023-12-11 14:00:01] [autobuild] [INFO] Changes detected - recompiling the module! :source
# [2023-12-11 14:00:01] [build-stdout] [2023-12-11 14:00:01] [autobuild] [INFO] Compiling 1 source file with javac [debug target 8] to target/classes
# [2023-12-11 14:00:06] [build-stdout] [2023-12-11 14:00:06] [autobuild] [INFO]
# [2023-12-11 14:00:06] [build-stdout] [2023-12-11 14:00:06] [autobuild] [INFO] --- resources:3.3.1:testResources (default-testResources) @ Study ---
# [2023-12-11 14:00:06] [build-stdout] [2023-12-11 14:00:06] [autobuild] [INFO] skip non existing resourceDirectory /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/d1843d8c-df5b-429c-ba8c-1fff659fc7f7_0/src/test/resources
# [2023-12-11 14:00:06] [build-stdout] [2023-12-11 14:00:06] [autobuild] [INFO]
# [2023-12-11 14:00:06] [build-stdout] [2023-12-11 14:00:06] [autobuild] [INFO] --- compiler:3.11.0:testCompile (default-testCompile) @ Study ---
# [2023-12-11 14:00:06] [build-stdout] [2023-12-11 14:00:06] [autobuild] [INFO] No sources to compile
# [2023-12-11 14:00:06] [build-stdout] [2023-12-11 14:00:06] [autobuild] [INFO]
# [2023-12-11 14:00:06] [build-stdout] [2023-12-11 14:00:06] [autobuild] [INFO] --- surefire:3.2.2:test (default-test) @ Study ---
# [2023-12-11 14:00:07] [build-stdout] [2023-12-11 14:00:07] [autobuild] [WARNING]  Parameter 'skipExec' (user property 'maven.test.skip.exec') is deprecated: Use skipTests instead.
# [2023-12-11 14:00:07] [build-stdout] [2023-12-11 14:00:07] [autobuild] [INFO] Tests are skipped.
# [2023-12-11 14:00:07] [build-stdout] [2023-12-11 14:00:07] [autobuild] [INFO]
# [2023-12-11 14:00:07] [build-stdout] [2023-12-11 14:00:07] [autobuild] [INFO] --- jar:3.3.0:jar (default-jar) @ Study ---
# [2023-12-11 14:00:07] [build-stdout] [2023-12-11 14:00:07] [autobuild] [INFO] Building jar: /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/d1843d8c-df5b-429c-ba8c-1fff659fc7f7_0/target/Study-1.0.0.jar
# [2023-12-11 14:00:08] [build-stdout] [2023-12-11 14:00:08] [autobuild] [INFO] ------------------------------------------------------------------------
# [2023-12-11 14:00:08] [build-stdout] [2023-12-11 14:00:08] [autobuild] [INFO] BUILD SUCCESS
# [2023-12-11 14:00:08] [build-stdout] [2023-12-11 14:00:08] [autobuild] [INFO] ------------------------------------------------------------------------
# [2023-12-11 14:00:08] [build-stdout] [2023-12-11 14:00:08] [autobuild] [INFO] Total time:  8.253 s
# [2023-12-11 14:00:08] [build-stdout] [2023-12-11 14:00:08] [autobuild] [INFO] Finished at: 2023-12-11T14:00:08-05:00
# [2023-12-11 14:00:08] [build-stdout] [2023-12-11 14:00:08] [autobuild] [INFO] ------------------------------------------------------------------------
# Finalizing database at /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/database.
# [2023-12-11 14:00:08] [build-stderr] Scanning for files in /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/d1843d8c-df5b-429c-ba8c-1fff659fc7f7_0...
# [2023-12-11 14:00:08] [build-stderr] /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/database: Indexing files in in /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/d1843d8c-df5b-429c-ba8c-1fff659fc7f7_0...
# [2023-12-11 14:00:08] [build-stderr] Running command in /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/d1843d8c-df5b-429c-ba8c-1fff659fc7f7_0: [/Users/lsiddiqsunny/codeql-home/codeql/xml/tools/index-files.sh, /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/database/working/files-to-index4481748210717193664.list]
# Successfully created database at /Users/lsiddiqsunny/Documents/Notre_Dame/Research/DevGPT-Study/Java_maven/database.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/SpuriousJavadocParam.ql.
# [1/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/SpuriousJavadocParam.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocTypes.ql.
# [2/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocTypes.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/ImpossibleJavadocThrows.ql.
# [3/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/ImpossibleJavadocThrows.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocThrows.ql.
# [4/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocThrows.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocMethods.ql.
# [5/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocMethods.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocReturnValues.ql.
# [6/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocReturnValues.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocParameters.ql.
# [7/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Documentation/MissingJavadocParameters.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Types/GenericsConstructor.ql.
# [8/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Types/GenericsConstructor.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Types/GenericsReturnType.ql.
# [9/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Types/GenericsReturnType.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Types/GenericsVariable.ql.
# [10/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Types/GenericsVariable.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Declarations/MissingOverrideAnnotation.ql.
# [11/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Declarations/MissingOverrideAnnotation.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Declarations/NonPrivateField.ql.
# [12/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Declarations/NonPrivateField.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Declarations/NonFinalImmutableField.ql.
# [13/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Declarations/NonFinalImmutableField.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Deprecated Code/AvoidDeprecatedCallableAccess.ql.
# [14/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Deprecated Code/AvoidDeprecatedCallableAccess.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Statements/OneStatementPerLine.ql.
# [15/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Statements/OneStatementPerLine.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Statements/TerminateIfElseIfWithElse.ql.
# [16/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Statements/TerminateIfElseIfWithElse.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Statements/MissingDefaultInSwitch.ql.
# [17/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Statements/MissingDefaultInSwitch.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsRefTypes.ql.
# [18/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsRefTypes.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsMethods.ql.
# [19/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsMethods.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsVariables.ql.
# [20/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsVariables.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsConstants.ql.
# [21/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsConstants.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsPackages.ql.
# [22/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Naming/NamingConventionsPackages.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Java Objects/AvoidCloneableInterface.ql.
# [23/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Java Objects/AvoidCloneableInterface.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Java Objects/AvoidCloneMethodAccess.ql.
# [24/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Java Objects/AvoidCloneMethodAccess.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Java Objects/AvoidFinalizeOverride.ql.
# [25/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Java Objects/AvoidFinalizeOverride.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Java Objects/AvoidCloneOverride.ql.
# [26/26] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Advisory/Java Objects/AvoidCloneOverride.ql.
# Starting evaluation of codeql/java-queries/Advisory/Declarations/MissingOverrideAnnotation.ql.
# Starting evaluation of codeql/java-queries/Advisory/Declarations/NonFinalImmutableField.ql.
# [1/26 eval 421ms] Evaluation done; writing results to codeql/java-queries/Advisory/Declarations/MissingOverrideAnnotation.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Declarations/NonPrivateField.ql.
# Starting evaluation of codeql/java-queries/Advisory/Deprecated Code/AvoidDeprecatedCallableAccess.ql.
# [2/26 eval 8ms] Evaluation done; writing results to codeql/java-queries/Advisory/Declarations/NonFinalImmutableField.bqrs.
# [3/26 eval 2ms] Evaluation done; writing results to codeql/java-queries/Advisory/Declarations/NonPrivateField.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Documentation/ImpossibleJavadocThrows.ql.
# [4/26 eval 11ms] Evaluation done; writing results to codeql/java-queries/Advisory/Deprecated Code/AvoidDeprecatedCallableAccess.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Documentation/MissingJavadocMethods.ql.
# [5/26 eval 8ms] Evaluation done; writing results to codeql/java-queries/Advisory/Documentation/ImpossibleJavadocThrows.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Documentation/MissingJavadocParameters.ql.
# [6/26 eval 28ms] Evaluation done; writing results to codeql/java-queries/Advisory/Documentation/MissingJavadocMethods.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Documentation/MissingJavadocReturnValues.ql.
# Starting evaluation of codeql/java-queries/Advisory/Documentation/MissingJavadocThrows.ql.
# [7/26 eval 3ms] Evaluation done; writing results to codeql/java-queries/Advisory/Documentation/MissingJavadocParameters.bqrs.
# [8/26 eval 2ms] Evaluation done; writing results to codeql/java-queries/Advisory/Documentation/MissingJavadocReturnValues.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Documentation/MissingJavadocTypes.ql.
# [9/26 eval 22ms] Evaluation done; writing results to codeql/java-queries/Advisory/Documentation/MissingJavadocThrows.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Documentation/SpuriousJavadocParam.ql.
# Starting evaluation of codeql/java-queries/Advisory/Java Objects/AvoidCloneMethodAccess.ql.
# [10/26 eval 16ms] Evaluation done; writing results to codeql/java-queries/Advisory/Documentation/MissingJavadocTypes.bqrs.
# [11/26 eval 2ms] Evaluation done; writing results to codeql/java-queries/Advisory/Documentation/SpuriousJavadocParam.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Java Objects/AvoidCloneOverride.ql.
# [12/26 eval 4ms] Evaluation done; writing results to codeql/java-queries/Advisory/Java Objects/AvoidCloneMethodAccess.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Java Objects/AvoidCloneableInterface.ql.
# Starting evaluation of codeql/java-queries/Advisory/Java Objects/AvoidFinalizeOverride.ql.
# [13/26 eval 9ms] Evaluation done; writing results to codeql/java-queries/Advisory/Java Objects/AvoidCloneOverride.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Naming/NamingConventionsConstants.ql.
# [14/26 eval 2ms] Evaluation done; writing results to codeql/java-queries/Advisory/Java Objects/AvoidCloneableInterface.bqrs.
# [15/26 eval 3ms] Evaluation done; writing results to codeql/java-queries/Advisory/Java Objects/AvoidFinalizeOverride.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Naming/NamingConventionsMethods.ql.
# Starting evaluation of codeql/java-queries/Advisory/Naming/NamingConventionsPackages.ql.
# [16/26 eval 16ms] Evaluation done; writing results to codeql/java-queries/Advisory/Naming/NamingConventionsConstants.bqrs.
# [17/26 eval 2ms] Evaluation done; writing results to codeql/java-queries/Advisory/Naming/NamingConventionsMethods.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Naming/NamingConventionsRefTypes.ql.
# Starting evaluation of codeql/java-queries/Advisory/Naming/NamingConventionsVariables.ql.
# [18/26 eval 8ms] Evaluation done; writing results to codeql/java-queries/Advisory/Naming/NamingConventionsPackages.bqrs.
# [19/26 eval 2ms] Evaluation done; writing results to codeql/java-queries/Advisory/Naming/NamingConventionsRefTypes.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Statements/MissingDefaultInSwitch.ql.
# Starting evaluation of codeql/java-queries/Advisory/Statements/OneStatementPerLine.ql.
# [20/26 eval 2ms] Evaluation done; writing results to codeql/java-queries/Advisory/Naming/NamingConventionsVariables.bqrs.
# [21/26 eval 1ms] Evaluation done; writing results to codeql/java-queries/Advisory/Statements/MissingDefaultInSwitch.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Statements/TerminateIfElseIfWithElse.ql.
# Starting evaluation of codeql/java-queries/Advisory/Types/GenericsConstructor.ql.
# Starting evaluation of codeql/java-queries/Advisory/Types/GenericsReturnType.ql.
# [22/26 eval 6ms] Evaluation done; writing results to codeql/java-queries/Advisory/Statements/OneStatementPerLine.bqrs.
# [23/26 eval 1ms] Evaluation done; writing results to codeql/java-queries/Advisory/Types/GenericsConstructor.bqrs.
# [24/26 eval 2ms] Evaluation done; writing results to codeql/java-queries/Advisory/Statements/TerminateIfElseIfWithElse.bqrs.
# Starting evaluation of codeql/java-queries/Advisory/Types/GenericsVariable.ql.
# [25/26 eval 3ms] Evaluation done; writing results to codeql/java-queries/Advisory/Types/GenericsReturnType.bqrs.
# [26/26 eval 21ms] Evaluation done; writing results to codeql/java-queries/Advisory/Types/GenericsVariable.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Compatibility/JDK9/UnderscoreIdentifier.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Compatibility/JDK9/UnderscoreIdentifier.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Compatibility/JDK9/JdkInternalAccess.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Compatibility/JDK9/JdkInternalAccess.ql.
# Starting evaluation of codeql/java-queries/Compatibility/JDK9/JdkInternalAccess.ql.
# Starting evaluation of codeql/java-queries/Compatibility/JDK9/UnderscoreIdentifier.ql.
# [1/2 eval 115ms] Evaluation done; writing results to codeql/java-queries/Compatibility/JDK9/JdkInternalAccess.bqrs.
# [2/2 eval 74ms] Evaluation done; writing results to codeql/java-queries/Compatibility/JDK9/UnderscoreIdentifier.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Dependencies/UnusedMavenDependencyBinary.ql.
# [1/7] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Dependencies/UnusedMavenDependencyBinary.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Dependencies/MutualDependency.ql.
# [2/7] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Dependencies/MutualDependency.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Dependencies/UnusedMavenDependencySource.ql.
# [3/7] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Dependencies/UnusedMavenDependencySource.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Refactoring Opportunities/FeatureEnvy.ql.
# [4/7] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Refactoring Opportunities/FeatureEnvy.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Refactoring Opportunities/DeeplyNestedClass.ql.
# [5/7] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Refactoring Opportunities/DeeplyNestedClass.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Refactoring Opportunities/HubClasses.ql.
# [6/7] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Refactoring Opportunities/HubClasses.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Refactoring Opportunities/InappropriateIntimacy.ql.
# [7/7] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Architecture/Refactoring Opportunities/InappropriateIntimacy.ql.
# Starting evaluation of codeql/java-queries/Architecture/Dependencies/MutualDependency.ql.
# Starting evaluation of codeql/java-queries/Architecture/Dependencies/UnusedMavenDependencyBinary.ql.
# [1/7 eval 207ms] Evaluation done; writing results to codeql/java-queries/Architecture/Dependencies/MutualDependency.bqrs.
# Starting evaluation of codeql/java-queries/Architecture/Dependencies/UnusedMavenDependencySource.ql.
# [2/7 eval 6ms] Evaluation done; writing results to codeql/java-queries/Architecture/Dependencies/UnusedMavenDependencyBinary.bqrs.
# Starting evaluation of codeql/java-queries/Architecture/Refactoring Opportunities/DeeplyNestedClass.ql.
# [3/7 eval 26ms] Evaluation done; writing results to codeql/java-queries/Architecture/Dependencies/UnusedMavenDependencySource.bqrs.
# Starting evaluation of codeql/java-queries/Architecture/Refactoring Opportunities/FeatureEnvy.ql.
# [4/7 eval 11ms] Evaluation done; writing results to codeql/java-queries/Architecture/Refactoring Opportunities/DeeplyNestedClass.bqrs.
# Starting evaluation of codeql/java-queries/Architecture/Refactoring Opportunities/HubClasses.ql.
# [5/7 eval 48ms] Evaluation done; writing results to codeql/java-queries/Architecture/Refactoring Opportunities/FeatureEnvy.bqrs.
# Starting evaluation of codeql/java-queries/Architecture/Refactoring Opportunities/InappropriateIntimacy.ql.
# [6/7 eval 19ms] Evaluation done; writing results to codeql/java-queries/Architecture/Refactoring Opportunities/HubClasses.bqrs.
# [7/7 eval 15ms] Evaluation done; writing results to codeql/java-queries/Architecture/Refactoring Opportunities/InappropriateIntimacy.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# [1/2] No need to rerun /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Compatibility/JDK9/UnderscoreIdentifier.ql.
# [2/2] No need to rerun /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Compatibility/JDK9/JdkInternalAccess.ql.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Complexity/ComplexCondition.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Complexity/ComplexCondition.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Complexity/BlockWithTooManyStatements.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Complexity/BlockWithTooManyStatements.ql.
# Starting evaluation of codeql/java-queries/Complexity/BlockWithTooManyStatements.ql.
# Starting evaluation of codeql/java-queries/Complexity/ComplexCondition.ql.
# [1/2 eval 45ms] Evaluation done; writing results to codeql/java-queries/Complexity/BlockWithTooManyStatements.bqrs.
# [2/2 eval 12ms] Evaluation done; writing results to codeql/java-queries/Complexity/ComplexCondition.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/DeadCode/DeadEnumConstant.ql.
# ...
# [1/2 eval 466ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-601/UrlRedirect.bqrs.
# [2/2 eval 81ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-601/UrlRedirectLocal.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-611/XXE.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-611/XXE.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-611/XXELocal.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-611/XXELocal.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-611/XXE.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-611/XXELocal.ql.
# [1/2 eval 485ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-611/XXE.bqrs.
# [2/2 eval 129ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-611/XXELocal.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-614/InsecureCookie.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-614/InsecureCookie.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-614/InsecureCookie.ql.
# [1/1 eval 157ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-614/InsecureCookie.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-643/XPathInjection.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-643/XPathInjection.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-643/XPathInjection.ql.
# [1/1 eval 520ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-643/XPathInjection.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-676/PotentiallyDangerousFunction.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-676/PotentiallyDangerousFunction.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-676/PotentiallyDangerousFunction.ql.
# [1/1 eval 81ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-676/PotentiallyDangerousFunction.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-681/NumericCastTainted.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-681/NumericCastTainted.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-681/NumericCastTaintedLocal.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-681/NumericCastTaintedLocal.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-681/NumericCastTainted.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-681/NumericCastTaintedLocal.ql.
# [1/2 eval 99ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-681/NumericCastTainted.bqrs.
# [2/2 eval 41ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-681/NumericCastTaintedLocal.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/RegexInjection.ql.
# [1/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/RegexInjection.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/ReDoS.ql.
# [2/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/ReDoS.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/PolynomialReDoS.ql.
# [3/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-730/PolynomialReDoS.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-730/PolynomialReDoS.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-730/ReDoS.ql.
# [1/3 eval 127ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-730/PolynomialReDoS.bqrs.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-730/RegexInjection.ql.
# [2/3 eval 12ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-730/ReDoS.bqrs.
# [3/3 eval 447ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-730/RegexInjection.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-732/ReadingFromWorldWritableFile.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-732/ReadingFromWorldWritableFile.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-732/ReadingFromWorldWritableFile.ql.
# [1/1 eval 91ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-732/ReadingFromWorldWritableFile.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-749/UnsafeAndroidAccess.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-749/UnsafeAndroidAccess.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-749/UnsafeAndroidAccess.ql.
# [1/1 eval 122ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-749/UnsafeAndroidAccess.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-780/RsaWithoutOaep.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-780/RsaWithoutOaep.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-780/RsaWithoutOaep.ql.
# [1/1 eval 129ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-780/RsaWithoutOaep.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedPasswordField.ql.
# [1/4] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedPasswordField.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsSourceCall.ql.
# [2/4] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsSourceCall.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsComparison.ql.
# [3/4] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsComparison.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsApiCall.ql.
# [4/4] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-798/HardcodedCredentialsApiCall.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsApiCall.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsComparison.ql.
# [1/4 eval 96ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsApiCall.bqrs.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsSourceCall.ql.
# [2/4 eval 36ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsComparison.bqrs.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-798/HardcodedPasswordField.ql.
# [3/4 eval 33ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-798/HardcodedCredentialsSourceCall.bqrs.
# [4/4 eval 17ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-798/HardcodedPasswordField.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-807/TaintedPermissionsCheck.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-807/TaintedPermissionsCheck.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-807/ConditionalBypass.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-807/ConditionalBypass.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-807/ConditionalBypass.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-807/TaintedPermissionsCheck.ql.
# [1/2 eval 113ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-807/ConditionalBypass.bqrs.
# [2/2 eval 39ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-807/TaintedPermissionsCheck.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-829/InsecureDependencyResolution.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-829/InsecureDependencyResolution.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-829/InsecureDependencyResolution.ql.
# [1/1 eval 63ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-829/InsecureDependencyResolution.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-833/LockOrderInconsistency.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-833/LockOrderInconsistency.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-833/LockOrderInconsistency.ql.
# [1/1 eval 105ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-833/LockOrderInconsistency.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-835/InfiniteLoop.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-835/InfiniteLoop.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-835/InfiniteLoop.ql.
# [1/1 eval 101ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-835/InfiniteLoop.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-917/OgnlInjection.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-917/OgnlInjection.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-917/OgnlInjection.ql.
# [1/1 eval 529ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-917/OgnlInjection.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-918/RequestForgery.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-918/RequestForgery.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-918/RequestForgery.ql.
# [1/1 eval 561ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-918/RequestForgery.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-925/ImproperIntentVerification.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-925/ImproperIntentVerification.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-925/ImproperIntentVerification.ql.
# [1/1 eval 133ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-925/ImproperIntentVerification.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-926/ImplicitlyExportedAndroidComponent.ql.
# [1/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-926/ImplicitlyExportedAndroidComponent.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-926/ContentProviderIncompletePermissions.ql.
# [2/2] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-926/ContentProviderIncompletePermissions.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-926/ContentProviderIncompletePermissions.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-926/ImplicitlyExportedAndroidComponent.ql.
# [1/2 eval 42ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-926/ContentProviderIncompletePermissions.bqrs.
# [2/2 eval 29ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-926/ImplicitlyExportedAndroidComponent.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/SensitiveResultReceiver.ql.
# [1/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/SensitiveResultReceiver.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/SensitiveCommunication.ql.
# [2/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/SensitiveCommunication.ql.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/ImplicitPendingIntents.ql.
# [3/3] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-927/ImplicitPendingIntents.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-927/ImplicitPendingIntents.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-927/SensitiveCommunication.ql.
# [1/3 eval 135ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-927/ImplicitPendingIntents.bqrs.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-927/SensitiveResultReceiver.ql.
# [2/3 eval 9ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-927/SensitiveCommunication.bqrs.
# [3/3 eval 58ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-927/SensitiveResultReceiver.bqrs.
# Shutting down query evaluator.
# Interpreting results.
# Running queries.
# Compiling query plan for /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-940/AndroidIntentRedirection.ql.
# [1/1] Found in cache: /Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-940/AndroidIntentRedirection.ql.
# Starting evaluation of codeql/java-queries/Security/CWE/CWE-940/AndroidIntentRedirection.ql.
# [1/1 eval 543ms] Evaluation done; writing results to codeql/java-queries/Security/CWE/CWE-940/AndroidIntentRedirection.bqrs.
# Shutting down query evaluator.
# Interpreting results.
