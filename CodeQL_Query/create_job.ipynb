# %%
file= """
CWE-020
CWE-022
CWE-023
CWE-074
CWE-078
CWE-079
CWE-089
CWE-090
CWE-094
CWE-1104
CWE-113
CWE-117
CWE-1204
CWE-129
CWE-134
CWE-190
CWE-200
CWE-209
CWE-266
CWE-273
CWE-295
CWE-297
CWE-312
CWE-319
CWE-326
CWE-327
CWE-335
CWE-338
CWE-347
CWE-352
CWE-367
CWE-421
CWE-441
CWE-470
CWE-489
CWE-501
CWE-502
CWE-522
CWE-524
CWE-532
CWE-601
CWE-611
CWE-614
CWE-643
CWE-676
CWE-681
CWE-730
CWE-732
CWE-749
CWE-780
CWE-798
CWE-807
CWE-829
CWE-833
CWE-835
CWE-917
CWE-918
CWE-925
CWE-926
CWE-927
CWE-940
"""

# %%
for f in file.split("\n"):
   print(f'codeql database analyze ./database/ "/Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/{f}" --format=csv --output="./Output/DistributedMiningNetwork/Security_{f}.csv"')
# Out:
# codeql database analyze ./database/ "/Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/" --format=csv --output="./Output/DistributedMiningNetwork/Security_.csv"
# codeql database analyze ./database/ "/Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-020" --format=csv --output="./Output/DistributedMiningNetwork/Security_CWE-020.csv"
# codeql database analyze ./database/ "/Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-022" --format=csv --output="./Output/DistributedMiningNetwork/Security_CWE-022.csv"
# codeql database analyze ./database/ "/Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-023" --format=csv --output="./Output/DistributedMiningNetwork/Security_CWE-023.csv"
# codeql database analyze ./database/ "/Users/lsiddiqsunny/codeql-home/codeql-repo/java/ql/src/Security/CWE/CWE-074" --format=csv --output="./Output/DistributedMiningNetwork/Security_CWE-074.csv"
# ...
